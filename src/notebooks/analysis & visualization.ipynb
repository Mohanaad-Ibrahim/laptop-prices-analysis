# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
font_dict = {
    "fontfamily":"times new roman",
    "fontsize":30,
    "color":"#25004C",
    "style":"italic"
}

# %%
df=pd.read_csv("../data/feature_engineered/feature_engineered_data.csv")

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution is_touch_screen  is_HD  \
# 0             IPS Panel Retina Display 2560x1600  No TouchScreen  False
# 1                                       1440x900  No TouchScreen  False
# 2                              Full HD 1920x1080  No TouchScreen   True
# 3             IPS Panel Retina Display 2880x1800  No TouchScreen  False
# 4             IPS Panel Retina Display 2560x1600  No TouchScreen  False
# ...

# %%
df["Company"].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df["Company"].value_counts().index
df["Company"].value_counts().values
plt.figure(figsize=(18,4))

plt.bar(
    x=df["Company"].value_counts().index,
    height=df["Company"].value_counts().values,
    color=["#22A9B2", "#22A9B2", "#22A9B2", "#DC1507"] + ["#22A9B2"] * 15

)
plt.xticks(**font_dict,rotation=90);

# %%
x=["x","w","e"]
y=[17,208,5]

plt.figure(figsize=(18,4))

plt.bar(x=x,height=y);

# %%
plt.figure(figsize=(18,4))
plt.bar(
    x=df["TypeName"].value_counts().index,
    height=df["TypeName"].value_counts().values,
    color=["#E0D4D4","#E0D4D4","#240D0D"]+["#E0D4D4"]*3

)
# Out:
# <BarContainer object of 6 artists>

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution is_touch_screen  is_HD  \
# 0             IPS Panel Retina Display 2560x1600  No TouchScreen  False
# 1                                       1440x900  No TouchScreen  False
# 2                              Full HD 1920x1080  No TouchScreen   True
# 3             IPS Panel Retina Display 2880x1800  No TouchScreen  False
# 4             IPS Panel Retina Display 2560x1600  No TouchScreen  False
# ...

# %%
df["is_touch_screen"].value_counts().index
df["is_touch_screen"].value_counts().values
plt.figure(figsize=(18,4))
plt.bar(
    x=df["is_touch_screen"].value_counts().index,
    height=df["is_touch_screen"].value_counts().values,
    color=["#ED1515","#CEC5CC"]
);

plt.title("comparison between touchscreen & no touchscreen",fontdict=font_dict);
plt.yticks(**font_dict);
plt.xticks(**font_dict,rotation=45);
